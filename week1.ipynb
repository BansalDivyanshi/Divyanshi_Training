# %%
import random
import time
from datetime import datetime

sensor_data = []
for i in range(5):
    for j in range (10):
        reading = {
            "sensor" : "sensor" + str(i),
            "timestamp" : datetime.now().isoformat(),
            "temperature": round(random.uniform(20.0, 40.0), 2)
        }
        sensor_data.append(reading)

for entry in sensor_data:
    print(entry['timestamp'] + " | " + entry['sensor'] + " | " + str(entry['temperature']) + "°C")
# Out:
# 2025-06-03T10:58:51.855379 | sensor0 | 28.13°C
# 2025-06-03T10:58:51.855395 | sensor0 | 25.25°C
# 2025-06-03T10:58:51.855399 | sensor0 | 29.42°C
# 2025-06-03T10:58:51.855402 | sensor0 | 25.05°C
# 2025-06-03T10:58:51.855404 | sensor0 | 30.3°C
# 2025-06-03T10:58:51.855407 | sensor0 | 24.09°C
# 2025-06-03T10:58:51.855409 | sensor0 | 26.89°C
# 2025-06-03T10:58:51.855412 | sensor0 | 31.29°C
# 2025-06-03T10:58:51.855414 | sensor0 | 39.69°C
# 2025-06-03T10:58:51.855416 | sensor0 | 32.65°C
# 2025-06-03T10:58:51.855419 | sensor1 | 33.99°C
# 2025-06-03T10:58:51.855421 | sensor1 | 36.44°C
# 2025-06-03T10:58:51.855423 | sensor1 | 31.55°C
# 2025-06-03T10:58:51.855426 | sensor1 | 36.62°C
# 2025-06-03T10:58:51.855428 | sensor1 | 22.8°C
# 2025-06-03T10:58:51.855430 | sensor1 | 33.27°C
# 2025-06-03T10:58:51.855432 | sensor1 | 21.41°C
# 2025-06-03T10:58:51.855435 | sensor1 | 23.71°C
# 2025-06-03T10:58:51.855437 | sensor1 | 22.58°C
# 2025-06-03T10:58:51.855439 | sensor1 | 21.18°C
# 2025-06-03T10:58:51.855442 | sensor2 | 36.8°C
# 2025-06-03T10:58:51.855444 | sensor2 | 23.86°C
# 2025-06-03T10:58:51.855446 | sensor2 | 21.24°C
# 2025-06-03T10:58:51.855448 | sensor2 | 34.36°C
# 2025-06-03T10:58:51.855450 | sensor2 | 32.1°C
# 2025-06-03T10:58:51.855453 | sensor2 | 37.07°C
# 2025-06-03T10:58:51.855455 | sensor2 | 37.32°C
# 2025-06-03T10:58:51.855457 | sensor2 | 34.57°C
# 2025-06-03T10:58:51.855459 | sensor2 | 27.0°C
# 2025-06-03T10:58:51.855461 | sensor2 | 23.33°C
# 2025-06-03T10:58:51.855464 | sensor3 | 24.83°C
# 2025-06-03T10:58:51.855466 | sensor3 | 35.8°C
# 2025-06-03T10:58:51.855468 | sensor3 | 31.86°C
# 2025-06-03T10:58:51.855470 | sensor3 | 32.33°C
# 2025-06-03T10:58:51.855473 | sensor3 | 34.92°C
# 2025-06-03T10:58:51.855475 | sensor3 | 26.74°C
# 2025-06-03T10:58:51.855477 | sensor3 | 36.95°C
# 2025-06-03T10:58:51.855479 | sensor3 | 26.18°C
# 2025-06-03T10:58:51.855481 | sensor3 | 26.79°C
# 2025-06-03T10:58:51.855483 | sensor3 | 38.42°C
# 2025-06-03T10:58:51.855486 | sensor4 | 30.39°C
# 2025-06-03T10:58:51.855488 | sensor4 | 35.46°C
# 2025-06-03T10:58:51.855490 | sensor4 | 31.8°C
# 2025-06-03T10:58:51.855492 | sensor4 | 37.83°C
# 2025-06-03T10:58:51.855495 | sensor4 | 33.21°C
# 2025-06-03T10:58:51.855497 | sensor4 | 36.82°C
# 2025-06-03T10:58:51.855499 | sensor4 | 22.44°C
# 2025-06-03T10:58:51.855501 | sensor4 | 38.07°C
# 2025-06-03T10:58:51.855503 | sensor4 | 24.23°C
# 2025-06-03T10:58:51.855506 | sensor4 | 23.17°C

# %%
summary = {}

for entry in sensor_data:
    sensor_name = entry["sensor"]
    temperature = entry["temperature"]

    if sensor_name not in summary:
        summary[sensor_name] = []

    summary[sensor_name].append(temperature)

summary
# Out:
# {'sensor0': [28.13,
#   25.25,
#   29.42,
#   25.05,
#   30.3,
#   24.09,
#   26.89,
#   31.29,
#   39.69,
#   32.65],
#  'sensor1': [33.99,
#   36.44,
#   31.55,
#   36.62,
#   22.8,
#   33.27,
#   21.41,
#   23.71,
#   22.58,
#   21.18],
#  'sensor2': [36.8,
#   23.86,
#   21.24,
#   34.36,
#   32.1,
#   37.07,
#   37.32,
#   34.57,
#   27.0,
#   23.33],
#  'sensor3': [24.83,
#   35.8,
#   31.86,
#   32.33,
#   34.92,
#   26.74,
#   36.95,
#   26.18,
#   26.79,
#   38.42],
#  'sensor4': [30.39,
#   35.46,
#   31.8,
#   37.83,
#   33.21,
#   36.82,
#   22.44,
#   38.07,
#   24.23,
#   23.17]}

# %%
for sensor_name in summary:
    temperatures = summary[sensor_name]

    avg_temp = sum(temperatures) / len(temperatures)
    max_temp = max(temperatures)
    min_temp = min(temperatures)
    
    print(sensor_name + ":")
    print("  Avg Temperature: " + str((avg_temp)) + "°C")
    print("  Max Temperature: " + str((max_temp)) + "°C")
    print("  Min Temperature: " + str((min_temp)) + "°C")
# Out:
# sensor0:
#   Avg Temperature: 29.276°C
#   Max Temperature: 39.69°C
#   Min Temperature: 24.09°C
# sensor1:
#   Avg Temperature: 28.355°C
#   Max Temperature: 36.62°C
#   Min Temperature: 21.18°C
# sensor2:
#   Avg Temperature: 30.764999999999997°C
#   Max Temperature: 37.32°C
#   Min Temperature: 21.24°C
# sensor3:
#   Avg Temperature: 31.482000000000006°C
#   Max Temperature: 38.42°C
#   Min Temperature: 24.83°C
# sensor4:
#   Avg Temperature: 31.342000000000002°C
#   Max Temperature: 38.07°C
#   Min Temperature: 22.44°C
